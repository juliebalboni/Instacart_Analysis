# %% [markdown]
# # 4.8 Grouping & Aggregating Part 2 - Task Exercises

# %% [markdown]
# ### Contents
# 01 Import Libraries and Data
#
# 02 Group by department_id and Find Mean
#
# 03 Loyalty Flag
#
# 04 Spending Flag
#
# 05 Order Frequency Flag
#
# 06 Export Data

# %% [markdown]
# ### 01 Import Libraries and Data

# %% [markdown]
# 1. Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Create path variable
path = r'D:\JupyterProjects\06-2022 Instacart Basket Analysis'

# %%
# Import pickle file
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Four8NanData.pkl'))

# %%
# Check shape of dataframe
ords_prods_merge.shape
# Out:
# (32404859, 21)

# %%
# Check head of dataframe
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
# 5                    19.0         False         196                  1
# 6                    20.0         False         196                  1
# 7                    14.0         False         196                  2
# 8                     0.0         False         196                  4
# 9                    30.0         False         196                  1
#
#    reordered  ... aisle_id  department_id  prices  _merge    price_range_loc  \
# 0          0  ...       77              7     9.0    both  Mid-range product
# 1          1  ...       77              7     9.0    both  Mid-range product
# 2          1  ...       77              7     9.0    both  Mid-range product
# 3          1  ...       77              7     9.0    both  Mid-range product
# 4          1  ...       77              7     9.0    both  Mid-range product
# 5          1  ...       77              7     9.0    both  Mid-range product
# 6          1  ...       77              7     9.0    both  Mid-range product
# 7          1  ...       77              7     9.0    both  Mid-range product
# 8          1  ...       77              7     9.0    both  Mid-range product
# 9          1  ...       77              7     9.0    both  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day max_order  \
# 0  Regularly busy  Regularly busy        Average orders        10
# 1  Regularly busy    Slowest days        Average orders        10
# 2  Regularly busy    Slowest days        Average orders        10
# 3      Least busy    Slowest days        Average orders        10
# 4      Least busy    Slowest days        Average orders        10
# 5  Regularly busy  Regularly busy        Average orders        10
# 6  Regularly busy    Busiest days        Average orders        10
# 7  Regularly busy    Busiest days        Average orders        10
# 8  Regularly busy    Busiest days        Average orders        10
# 9      Least busy    Slowest days        Average orders        10
#
#    loyalty_flag
# 0  New customer
# 1  New customer
# 2  New customer
# 3  New customer
# 4  New customer
# 5  New customer
# 6  New customer
# 7  New customer
# 8  New customer
# 9  New customer
#
# [10 rows x 21 columns]

# %% [markdown]
# ### 02 Group by department_id and Find Mean

# %% [markdown]
# 2. In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
# Find the average number of orders by department in data subset
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# 3. Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a
# markdown cell below the executed code.

# %% [markdown]
# The means for the entire dataframe range from 15 to 23 whereas the mean from the data subset ranged from 11 - 19.  Also, all 21 departments are included in the entire dataframe while the data subset only contained 8 of them.

# %% [markdown]
# ### 03 Loyalty Flag

# %%
# View loyalty_flag frequencies for loyalty_flag field created in first part of excercise
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# 5. The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
# Group by loyalty_flag and find mean, min, and max using the aggregate() function
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.773438  1.0  25.0
# New customer      7.800781  1.0  25.0
# Regular customer  7.796875  1.0  25.0

# %% [markdown]
# The average prices of products purchased by loyal customers are lower than those for new customers and regular customers.

# %% [markdown]
# ### 04 Spending Flag

# %% [markdown]
# 6. The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Create mean_price column by applying transform () function to prices grouped by user_id
ords_prods_merge['mean_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Create spending flag for <10
ords_prods_merge.loc[ords_prods_merge['mean_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Create spending flag for >= 10
ords_prods_merge.loc[ords_prods_merge['mean_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Check spending_flag frequencies
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     32284736
# High spender      120123
# Name: spending_flag, dtype: int64

# %%
# View top ten rows
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
# 5                    19.0         False         196                  1
# 6                    20.0         False         196                  1
# 7                    14.0         False         196                  2
# 8                     0.0         False         196                  4
# 9                    30.0         False         196                  1
#
#    reordered  ... prices  _merge    price_range_loc     busiest_day  \
# 0          0  ...    9.0    both  Mid-range product  Regularly busy
# 1          1  ...    9.0    both  Mid-range product  Regularly busy
# 2          1  ...    9.0    both  Mid-range product  Regularly busy
# 3          1  ...    9.0    both  Mid-range product      Least busy
# 4          1  ...    9.0    both  Mid-range product      Least busy
# 5          1  ...    9.0    both  Mid-range product  Regularly busy
# 6          1  ...    9.0    both  Mid-range product  Regularly busy
# 7          1  ...    9.0    both  Mid-range product  Regularly busy
# 8          1  ...    9.0    both  Mid-range product  Regularly busy
# 9          1  ...    9.0    both  Mid-range product      Least busy
#
#      busiest_days busiest_period_of_day max_order  loyalty_flag mean_price  \
# 0  Regularly busy        Average orders        10  New customer   6.367188
# 1    Slowest days        Average orders        10  New customer   6.367188
# 2    Slowest days        Average orders        10  New customer   6.367188
# 3    Slowest days        Average orders        10  New customer   6.367188
# 4    Slowest days        Average orders        10  New customer   6.367188
# 5  Regularly busy        Average orders        10  New customer   6.367188
# 6    Busiest days        Average orders        10  New customer   6.367188
# 7    Busiest days        Average orders        10  New customer   6.367188
# 8    Busiest days        Average orders        10  New customer   6.367188
# 9    Slowest days        Average orders        10  New customer   6.367188
#
#    spending_flag
# 0    Low spender
# 1    Low spender
# 2    Low spender
# 3    Low spender
# 4    Low spender
# 5    Low spender
# 6    Low spender
# 7    Low spender
# 8    Low spender
# 9    Low spender
#
# [10 rows x 23 columns]

# %% [markdown]
# ### 05 Order Frequency Flag

# %% [markdown]
# 7. In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# Create median_days_prior column by applying transform () function to days_since_prior_order grouped by user_id
ords_prods_merge['median_days_prior'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Create frequency flag - Non-frequent customer
ords_prods_merge.loc[ords_prods_merge['median_days_prior'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
# Create frequency flag - Regular customer
ords_prods_merge.loc[(ords_prods_merge['median_days_prior'] > 10) & (ords_prods_merge['median_days_prior'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
# Create frequency flag - Frequent customer
ords_prods_merge.loc[ords_prods_merge['median_days_prior'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Check frequency_flag frequencies
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: frequency_flag, dtype: int64

# %%
ords_prods_merge[['days_since_prior_order', 'median_days_prior', 'frequency_flag']].head(30)
# Out:
#     days_since_prior_order  median_days_prior         frequency_flag
# 0                      NaN               20.5  Non-frequent customer
# 1                     15.0               20.5  Non-frequent customer
# 2                     21.0               20.5  Non-frequent customer
# 3                     29.0               20.5  Non-frequent customer
# 4                     28.0               20.5  Non-frequent customer
# 5                     19.0               20.5  Non-frequent customer
# 6                     20.0               20.5  Non-frequent customer
# 7                     14.0               20.5  Non-frequent customer
# 8                      0.0               20.5  Non-frequent customer
# 9                     30.0               20.5  Non-frequent customer
# 10                     7.0               10.0      Frequent customer
# 11                     8.0               10.0      Frequent customer
# 12                     7.0               10.0      Frequent customer
# 13                     7.0               10.0      Frequent customer
# 14                    14.0               10.0      Frequent customer
# 15                     6.0                6.0      Frequent customer
# 16                     8.0                6.0      Frequent customer
# 17                     6.0                6.0      Frequent customer
# 18                     6.0                7.5      Frequent customer
# 19                     7.0                6.0      Frequent customer
# 20                     8.0                6.0      Frequent customer
# 21                     4.0               10.0      Frequent customer
# 22                     3.0               10.0      Frequent customer
# 23                     NaN                8.0      Frequent customer
# 24                     7.0                8.0      Frequent customer
# 25                     7.0                8.0      Frequent customer
# 26                     8.0                8.0      Frequent customer
# 27                     8.0                8.0      Frequent customer
# 28                     7.0                8.0      Frequent customer
# 29                     8.0                8.0      Frequent customer

# %%
ords_prods_merge.dtypes
# Out:
# order_id                     int32
# user_id                      int32
# order_number                  int8
# orders_day_of_week            int8
# order_hour_of_day             int8
# days_since_prior_order     float16
# new_customer                  bool
# product_id                   int32
# add_to_cart_order            int16
# reordered                     int8
# product_name                object
# aisle_id                     int16
# department_id                 int8
# prices                     float16
# _merge                    category
# price_range_loc             object
# busiest_day                 object
# busiest_days                object
# busiest_period_of_day       object
# max_order                    int16
# loyalty_flag                object
# mean_price                 float16
# spending_flag               object
# median_days_prior          float16
# frequency_flag              object
# dtype: object

# %% [markdown]
# ### 06 Export Data

# %%
# Export ords_prods_merge as 4_8_Data in pickle format
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'Four8Final.pkl'))
